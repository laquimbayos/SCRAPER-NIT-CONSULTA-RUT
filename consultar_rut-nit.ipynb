# %%
import pandas as pd
import pyautogui
import pyperclip
import time
import os
from PIL import ImageEnhance
from PIL import Image
import pytesseract
from PIL import ImageEnhance
import pyautogui
from PIL import Image
import pyautogui
import pytesseract
import cv2
import numpy as np
from pynput import mouse
import re
import tkinter as tk
from tkinter import simpledialog
from tkinter import messagebox


#==================================================================

data = pd.read_excel("Documentos.xlsx", "Data")
documentos = list(data["Documentos sin DV"].unique())

root = tk.Tk()
root.withdraw()  # Oculta la ventana principal

# Mostrar el cuadro de entrada
archivo = simpledialog.askstring(title="Ingreso de datos",prompt="Escribe el nombre del archivo a guardar:")

lista_info = []


for numero in documentos:
    numero = str(numero)


    #====================Nueva pestaña opcion 1============================

    nombre_imagen = "nueva_pestana.png"
    try:
        ubicacion = pyautogui.locateOnScreen(nombre_imagen, confidence=0.7)
        
        if ubicacion:
            centro = pyautogui.center(ubicacion)
            pyautogui.moveTo(centro)
            pyautogui.click()

        else:
            0
            
    except pyautogui.ImageNotFoundException:
        0
    except Exception as e:
        0
            
    if nombre_imagen in ["buscador_google.png", "nit.png"]:
        pyperclip.copy(numero)
        pyautogui.hotkey('ctrl', 'v')
        # pyautogui.press('enter')

    #====================Nueva pestaña opcion 2============================

    nombre_imagen = "nueva_pestana_1.png"
    try:
        ubicacion = pyautogui.locateOnScreen(nombre_imagen, confidence=0.7)
        
        if ubicacion:
            centro = pyautogui.center(ubicacion)
            pyautogui.moveTo(centro)
            pyautogui.click()
            0
        else:
            0
            
    except pyautogui.ImageNotFoundException:
        0
    except Exception as e:
        0
            
    if nombre_imagen in ["buscador_google.png", "nit.png"]:
        pyperclip.copy(numero)
        pyautogui.hotkey('ctrl', 'v')
        pyautogui.press('enter')

    #====================Espera===================================
    time.sleep(0.5)
    #====================Cerrar pestaña============================
    nombre_imagen = "cerrar_pestana.png"
    try:
        ubicacion = pyautogui.locateOnScreen(nombre_imagen, confidence=0.7)
        
        if ubicacion:
            centro = pyautogui.center(ubicacion)
            pyautogui.moveTo(centro)
            pyautogui.click()
            0
        else:
            0
            
    except pyautogui.ImageNotFoundException:
        0
    except Exception as e:
        0
            
    if nombre_imagen in ["buscador_google.png", "nit.png"]:
        pyperclip.copy(numero)
        pyautogui.hotkey('ctrl', 'v')
        pyautogui.press('enter')
    #====================Espera===================================
    time.sleep(0)
    #====================Definir URLL===================================
    url = "https://muisca.dian.gov.co/WebRutMuisca/DefConsultaEstadoRUT.faces"
    #====================Buscar imagen del buscardor===================================
    nombre_imagen = "buscador_google.png"
    try:
        ubicacion = pyautogui.locateOnScreen(nombre_imagen, confidence=0.7)
        
        if ubicacion:
            centro = pyautogui.center(ubicacion)
            pyautogui.moveTo(centro)
            pyautogui.click()
            0
        else:
            0
            
    except pyautogui.ImageNotFoundException:
        0
    except Exception as e:
        0
            
    if nombre_imagen in ["buscador_google.png", "nit.png"]:
        pyperclip.copy(url)
        pyautogui.hotkey('ctrl', 'v')
        pyautogui.press('enter')
    #====================Espera===================================
    time.sleep(1)
    #====================Copiar nuemro===================================
    pyperclip.copy(numero)
    #====================chulear captcha===================================
    nombre_imagen = "chulear_captcha.png"
    try:
        ubicacion = pyautogui.locateOnScreen(nombre_imagen, confidence=0.7)
        
        if ubicacion:
            centro = pyautogui.center(ubicacion)
            pyautogui.moveTo(centro)
            pyautogui.click()
            0
        else:
            0
            
    except pyautogui.ImageNotFoundException:
        0
    except Exception as e:
        0
            
    if nombre_imagen in ["buscador_google.png", "nit.png"]:
        pyperclip.copy(url)
        pyautogui.hotkey('ctrl', 'v')
        # pyautogui.press('enter')
    #====================chulear captcha===================================
    nombre_imagen = "chulear_captcha.png"
    try:
        ubicacion = pyautogui.locateOnScreen(nombre_imagen, confidence=0.7)
        
        if ubicacion:
            centro = pyautogui.center(ubicacion)
            pyautogui.moveTo(centro)
            pyautogui.click()
            0
        else:
            0
            
    except pyautogui.ImageNotFoundException:
        0
    except Exception as e:
        0
            
    if nombre_imagen in ["buscador_google.png", "nit.png"]:
        pyperclip.copy(url)
        pyautogui.hotkey('ctrl', 'v')
        # pyautogui.press('enter')
    
    #====================chulear captcha===================================
    nombre_imagen = "chulear_captcha.png"
    try:
        ubicacion = pyautogui.locateOnScreen(nombre_imagen, confidence=0.7)
        
        if ubicacion:
            centro = pyautogui.center(ubicacion)
            pyautogui.moveTo(centro)
            pyautogui.click()
            0
        else:
            0
            
    except pyautogui.ImageNotFoundException:
        0
    except Exception as e:
        0
            
    if nombre_imagen in ["buscador_google.png", "nit.png"]:
        pyperclip.copy(url)
        pyautogui.hotkey('ctrl', 'v')
        # pyautogui.press('enter')
    #====================chulear captcha===================================
    nombre_imagen = "chulear_captcha.png"
    try:
        ubicacion = pyautogui.locateOnScreen(nombre_imagen, confidence=0.7)
        
        if ubicacion:
            centro = pyautogui.center(ubicacion)
            pyautogui.moveTo(centro)
            pyautogui.click()
            0
        else:
            0
            
    except pyautogui.ImageNotFoundException:
        0
    except Exception as e:
        0
            
    if nombre_imagen in ["buscador_google.png", "nit.png"]:
        pyperclip.copy(url)
        pyautogui.hotkey('ctrl', 'v')
        # pyautogui.press('enter')

    #====================Espera===================================
    time.sleep(1)
    #====================Pegar numero en el buscador=================================
    nombre_imagen = "nit.png"
    try:
        ubicacion = pyautogui.locateOnScreen(nombre_imagen, confidence=0.7)
        
        if ubicacion:
            centro = pyautogui.center(ubicacion)
            pyautogui.moveTo(centro)
            pyautogui.click()
            0
        else:
            0
            
    except pyautogui.ImageNotFoundException:
        0
    except Exception as e:
        0
            
    if nombre_imagen in ["buscador_google.png", "nit.png"]:
        pyperclip.copy(numero)
        pyautogui.hotkey('ctrl', 'v')
        # pyautogui.press('enter')
    #====================Espera===================================
    time.sleep(1) #Importante
    #====================otra vez captcha===================================
    nombre_imagen = "chulear_captcha.png"
    try:
        ubicacion = pyautogui.locateOnScreen(nombre_imagen, confidence=0.7)
        
        if ubicacion:
            centro = pyautogui.center(ubicacion)
            pyautogui.moveTo(centro)
            pyautogui.click()
            0
        else:
            0
            
    except pyautogui.ImageNotFoundException:
        0
    except Exception as e:
        0
            
    if nombre_imagen in ["buscador_google.png", "nit.png"]:
        pyperclip.copy(url)
        pyautogui.hotkey('ctrl', 'v')
        # pyautogui.press('enter')
    #====================Espera===================================
    time.sleep(4) #Importante
    #====================Clic en buscar=================================
    nombre_imagen = "buscar.png"
    try:
        ubicacion = pyautogui.locateOnScreen(nombre_imagen, confidence=0.7)
        
        if ubicacion:
            centro = pyautogui.center(ubicacion)
            pyautogui.moveTo(centro)
            pyautogui.click()
            0
        else:
            0
            
    except pyautogui.ImageNotFoundException:
        0
    except Exception as e:
        0
            
    if nombre_imagen in ["buscador_google.png", "nit.png"]:
        pyperclip.copy(numero)
        pyautogui.hotkey('ctrl', 'v')
        # pyautogui.press('enter')  #Atento
    #====================Espera===================================
    time.sleep(4) #Importante



    #====================Obtener HTML===================================
    nombre_imagen = "blanco_1.png"
    nombre_imagen_2 = "blanco_2.png"
    pyautogui.hotkey('ctrl', 'u')
    pyautogui.hotkey('ctrl', 'a')
    time.sleep(1)
    pyautogui.hotkey('ctrl', 'c')
    time.sleep(1)
    html = pyperclip.paste()

    #====================extraer info del  HTML===================================
    nombre = html

    resultado = {}
    primer_nombre = 0
    otros_nombres = 0
    primer_apellido = 0
    segundo_apellido = 0
    nombre_completo = 0
    razon_social = 0

    if "primerNombre" in nombre:
        def extraer_etiqueta(etiqueta):
            patron = f'{etiqueta}">(.*?)<'
            match = re.search(patron, nombre)
            return match.group(1).strip() if match else ""

        primer_nombre = extraer_etiqueta("primerNombre")
        otros_nombres = extraer_etiqueta("otrosNombres")
        primer_apellido = extraer_etiqueta("primerApellido")
        segundo_apellido = extraer_etiqueta("segundoApellido")

        nombre_completo = " ".join([primer_nombre, otros_nombres, primer_apellido, segundo_apellido]).strip()

        resultado = {"tipo": "persona",
                    "primer_nombre": primer_nombre,
                    "otros_nombres": otros_nombres,
                    "primer_apellido": primer_apellido,
                    "segundo_apellido": segundo_apellido,
                    "nombre_completo": nombre_completo,
                    "razon_social": 0}

    elif "razonSocial" in nombre:
        match = re.search(r'razonSocial">(.*?)<', nombre)
        razon_social = match.group(1).strip()
        resultado = {"tipo": "empresa",
                "primer_nombre": 0,
                "otros_nombres": 0,
                "primer_apellido": 0,
                "segundo_apellido": 0,
                "nombre_completo": 0,
                "razon_social": razon_social}

    resultado

    #====================Cerrar html=================================
    nombre_imagen = "cerrar_pestana.png"
    try:
        ubicacion = pyautogui.locateOnScreen(nombre_imagen, confidence=0.7)
        
        if ubicacion:
            centro = pyautogui.center(ubicacion)
            pyautogui.moveTo(centro)
            pyautogui.click()
            0
        else:
            0
            
    except pyautogui.ImageNotFoundException:
        0
    except Exception as e:
        0
            
    if nombre_imagen in ["buscador_google.png", "nit.png"]:
        pyperclip.copy(numero)
        pyautogui.hotkey('ctrl', 'v')
        # pyautogui.press('enter')  #Atento
        
    resultado["documento"] = numero
    lista_info.append(resultado)
    
    
df = pd.DataFrame(lista_info)

df.to_excel(archivo+".xlsx")


# Mostrar mensaje al finalizar
messagebox.showinfo(title="Búsqueda finalizada", message="El proceso ha terminado correctamente.")
# Out:
# 'ok'
